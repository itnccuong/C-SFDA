# %% [markdown]
# # C-SFDA Stage 2 - Kaggle Notebook
#
# ## Setup Instructions
# 1. Upload this notebook to Kaggle
# 2. Turn ON GPU: Settings → Accelerator → GPU P100
# 3. Run cells in order
#
# **Expected time:** 4-6 hours
# **Cost:** $0 (free tier)

# %% [markdown]
# ## Step 1: Setup Environment

# %%
# # Clone repository
# !git clone https://github.com/nazmul-karim170/C-SFDA_Source-Free-Domain-Adaptation.git
# %cd C-SFDA_Source-Free-Domain-Adaptation

# %%
# Uninstall any existing PyTorch and reinstall with CUDA support
# !pip install torch==2.0.1+cu118 torchvision==0.15.2+cu118 --index-url https://download.pytorch.org/whl/cu118
# !pip install hydra-core omegaconf scikit-learn tqdm wandb matplotlib
# !pip install 'numpy<2'  # Fix NumPy compatibility with torchvision 0.15.2
# Out:
# Looking in indexes: https://download.pytorch.org/whl/cu118
# Collecting torch==2.0.1+cu118
#   Downloading https://download.pytorch.org/whl/cu118/torch-2.0.1%2Bcu118-cp310-cp310-linux_x86_64.whl (2267.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 GB ?  0:00:46eta 0:00:0100:01m
# Collecting torchvision==0.15.2+cu118
#   Downloading https://download.pytorch.org/whl/cu118/torchvision-0.15.2%2Bcu118-cp310-cp310-linux_x86_64.whl (6.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.1/6.1 MB 21.7 MB/s  0:00:00m0:00:01
# Requirement already satisfied: filelock in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from torch==2.0.1+cu118) (3.20.0)
# Requirement already satisfied: typing-extensions in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from torch==2.0.1+cu118) (4.15.0)
# Requirement already satisfied: sympy in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from torch==2.0.1+cu118) (1.14.0)
# Requirement already satisfied: networkx in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from torch==2.0.1+cu118) (3.4.2)
# Requirement already satisfied: jinja2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from torch==2.0.1+cu118) (3.1.6)
# Collecting triton==2.0.0 (from torch==2.0.1+cu118)
#   Downloading https://download.pytorch.org/whl/triton-2.0.0-1-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (63.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.3/63.3 MB 66.8 MB/s  0:00:00m0:00:01
# Requirement already satisfied: numpy in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from torchvision==0.15.2+cu118) (1.26.4)
# Requirement already satisfied: requests in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from torchvision==0.15.2+cu118) (2.32.5)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from torchvision==0.15.2+cu118) (12.0.0)
# Collecting cmake (from triton==2.0.0->torch==2.0.1+cu118)
#   Downloading https://download.pytorch.org/whl/cmake-3.25.0-py2.py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (23.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 231.8 MB/s  0:00:00
# Collecting lit (from triton==2.0.0->torch==2.0.1+cu118)
#   Downloading https://download.pytorch.org/whl/lit-15.0.7.tar.gz (132 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: MarkupSafe>=2.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from jinja2->torch==2.0.1+cu118) (3.0.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from requests->torchvision==0.15.2+cu118) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from requests->torchvision==0.15.2+cu118) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from requests->torchvision==0.15.2+cu118) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from requests->torchvision==0.15.2+cu118) (2025.10.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from sympy->torch==2.0.1+cu118) (1.3.0)
# Building wheels for collected packages: lit
#   DEPRECATION: Building 'lit' using the legacy setup.py bdist_wheel mechanism, which will be removed in a future version. pip 25.3 will enforce this behaviour change. A possible replacement is to use the standardized build interface by setting the `--use-pep517` option, (possibly combined with `--no-build-isolation`), or adding a `pyproject.toml` file to the source tree of 'lit'. Discussion can be found at https://github.com/pypa/pip/issues/6334
#   Building wheel for lit (setup.py) ... done
#   Created wheel for lit: filename=lit-15.0.7-py3-none-any.whl size=90063 sha256=eba16e27952fb744f0bfb2e1c148a3f7b2c24daecbab06cd60149d4856e574e4
#   Stored in directory: /home/ec2-user/.cache/pip/wheels/27/2c/b6/3ed2983b1b44fe0dea1bb35234b09f2c22fb8ebb308679c922
# Successfully built lit
# Installing collected packages: lit, cmake, triton, torch, torchvision
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5/5 [torchvision] [torchvision]
# Successfully installed cmake-3.25.0 lit-15.0.7 torch-2.0.1+cu118 torchvision-0.15.2+cu118 triton-2.0.0
# Collecting hydra-core
#   Downloading hydra_core-1.3.2-py3-none-any.whl.metadata (5.5 kB)
# Requirement already satisfied: omegaconf in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (2.3.0)
# Requirement already satisfied: scikit-learn in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (1.7.2)
# Requirement already satisfied: tqdm in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (4.67.1)
# Collecting wandb
#   Downloading wandb-0.23.0-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Requirement already satisfied: matplotlib in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (3.10.7)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from hydra-core) (4.9.3)
# Requirement already satisfied: packaging in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from hydra-core) (24.2)
# Requirement already satisfied: PyYAML>=5.1.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from omegaconf) (6.0.3)
# Requirement already satisfied: numpy>=1.22.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from scikit-learn) (1.26.4)
# Requirement already satisfied: scipy>=1.8.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from scikit-learn) (1.15.2)
# Requirement already satisfied: joblib>=1.2.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from scikit-learn) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: click>=8.0.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from wandb) (8.3.0)
# Collecting gitpython!=3.1.29,>=1.0.0 (from wandb)
#   Using cached gitpython-3.1.45-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: platformdirs in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from wandb) (4.5.0)
# Requirement already satisfied: protobuf!=4.21.0,!=5.28.0,<7,>=3.19.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from wandb) (6.31.1)
# Requirement already satisfied: pydantic<3 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from wandb) (2.12.3)
# Requirement already satisfied: requests<3,>=2.0.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from wandb) (2.32.5)
# Collecting sentry-sdk>=2.0.0 (from wandb)
#   Downloading sentry_sdk-2.44.0-py2.py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: typing-extensions<5,>=4.8 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from wandb) (4.15.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from pydantic<3->wandb) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from pydantic<3->wandb) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from pydantic<3->wandb) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from requests<3,>=2.0.0->wandb) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from requests<3,>=2.0.0->wandb) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from requests<3,>=2.0.0->wandb) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from requests<3,>=2.0.0->wandb) (2025.10.5)
# Requirement already satisfied: contourpy>=1.0.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from matplotlib) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: pillow>=8 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from matplotlib) (12.0.0)
# Requirement already satisfied: pyparsing>=3 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from matplotlib) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from matplotlib) (2.9.0.post0)
# Collecting gitdb<5,>=4.0.1 (from gitpython!=3.1.29,>=1.0.0->wandb)
#   Using cached gitdb-4.0.12-py3-none-any.whl.metadata (1.2 kB)
# Collecting smmap<6,>=3.0.1 (from gitdb<5,>=4.0.1->gitpython!=3.1.29,>=1.0.0->wandb)
#   Using cached smmap-5.0.2-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: six>=1.5 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Downloading hydra_core-1.3.2-py3-none-any.whl (154 kB)
# Downloading wandb-0.23.0-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (20.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.2/20.2 MB 96.9 MB/s  0:00:006m0:00:01
# Using cached gitpython-3.1.45-py3-none-any.whl (208 kB)
# Using cached gitdb-4.0.12-py3-none-any.whl (62 kB)
# Using cached smmap-5.0.2-py3-none-any.whl (24 kB)
# Downloading sentry_sdk-2.44.0-py2.py3-none-any.whl (402 kB)
# Installing collected packages: smmap, sentry-sdk, hydra-core, gitdb, gitpython, wandb
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6/6 [wandb]32m5/6 [wandb]hon]]
# Successfully installed gitdb-4.0.12 gitpython-3.1.45 hydra-core-1.3.2 sentry-sdk-2.44.0 smmap-5.0.2 wandb-0.23.0
# Requirement already satisfied: numpy<2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (1.26.4)

# %%
# !conda install -c conda-forge libstdcxx-ng -y
# !conda install -c conda-forge pillow -y
# Out:
# Retrieving notices: done
# Channels:
#  - conda-forge
# Platform: linux-64
# Collecting package metadata (repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /home/ec2-user/anaconda3/envs/python3
#
#   added / updated specs:
#     - libstdcxx-ng
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     ca-certificates-2025.11.12 |       hbd8a1cb_0         149 KB  conda-forge
#     certifi-2025.11.12         |     pyhd8ed1ab_0         153 KB  conda-forge
#     openssl-3.6.0              |       h26f9b46_0         3.0 MB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         3.3 MB
#
# The following packages will be UPDATED:
#
#   ca-certificates                      2025.10.5-hbd8a1cb_0 --> 2025.11.12-hbd8a1cb_0
#   certifi                            2025.10.5-pyhd8ed1ab_0 --> 2025.11.12-pyhd8ed1ab_0
#   openssl                                  3.5.4-h26f9b46_0 --> 3.6.0-h26f9b46_0
#
#
#
# Downloading and Extracting Packages:
# openssl-3.6.0        | 3.0 MB    |                                       |   0%
# certifi-2025.11.12   | 153 KB    |                                       |   0%
#
# ca-certificates-2025 | 149 KB    |                                       |   0%
#
# ca-certificates-2025 | 149 KB    | ###9                                  |  11%
#
# openssl-3.6.0        | 3.0 MB    | 1                                     |   1%
# certifi-2025.11.12   | 153 KB    | ###8                                  |  10%
# certifi-2025.11.12   | 153 KB    | ##################################### | 100%
#
# ca-certificates-2025 | 149 KB    | ##################################### | 100%
#
#
#
#
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# Channels:
#  - conda-forge
# Platform: linux-64
# Collecting package metadata (repodata.json): done
# Solving environment: done
#
# # All requested packages already installed.

# %%
import os
import sys

# Force use of conda's libstdc++
conda_lib = '/home/ec2-user/anaconda3/envs/python3/lib'
if 'LD_LIBRARY_PATH' in os.environ:
    os.environ['LD_LIBRARY_PATH'] = f"{conda_lib}:{os.environ['LD_LIBRARY_PATH']}"
else:
    os.environ['LD_LIBRARY_PATH'] = conda_lib

# %%
# Verify GPU
import torch
print(f"PyTorch version: {torch.__version__}")
print(f"CUDA available: {torch.cuda.is_available()}")
if torch.cuda.is_available():
    print(f"GPU: {torch.cuda.get_device_name(0)}")
    print(f"VRAM: {torch.cuda.get_device_properties(0).total_memory / 1e9:.1f} GB")
else:
    print("⚠️ No GPU! Go to Settings → Accelerator → GPU P100")
# Out:
# PyTorch version: 2.0.1+cu118
# CUDA available: True
# GPU: NVIDIA A10G
# VRAM: 23.7 GB

# %% [markdown]
# ## Step 2: Download VisDA-C Dataset
#
# **About VisDA-C:**
# - Training domain: Synthetic object images (rendered from CAD models)
# - Validation domain: Real object images (cropped from COCO dataset)
# - 12 categories: aeroplane, bicycle, bus, car, horse, knife, motorcycle, person, plant, skateboard, train, truck
#
# **For Stage 2, you only need the VALIDATION set (target domain)**
#
# Choose one of the options below:

# %%
# # ==================== OPTION A: Direct Download (Recommended) ====================
# # Official VisDA-C dataset from Boston University server

# !mkdir -p data/VISDA-C

# # Download validation set (target domain) - ~5GB
# !wget -P data/VISDA-C http://csr.bu.edu/ftp/visda17/clf/validation.tar

# # Extract
# !tar -xvf data/VISDA-C/validation.tar -C data/VISDA-C/

# # Clean up tar files to save space
# !rm -f data/VISDA-C/*.tar

# !mv data/VISDA-C/validation/image_list.txt data/VISDA-C/validation_list.txt

# print("\n✓ Dataset downloaded!")

# %% [markdown]
# ## Step 3: Download Pre-trained Checkpoint

# %%
# # Download checkpoint from Google Drive
# # Link: https://drive.google.com/drive/folders/16vTNNzzAt4M1mmeLsOxSFDRzBogaNkJw

# !pip install -q gdown

# # Download specific file (replace FILE_ID with actual ID from Drive link)
# # Get FILE_ID by: Right-click file in Drive → Get link → Copy ID
# # Example: https://drive.google.com/file/d/1a2B3c4D5e6F7g8H9i0J/view → FILE_ID = 1a2B3c4D5e6F7g8H9i0J

# # !gdown --id FILE_ID_FOR_best_train_2020 -O checkpoint/best_train_2020.pth.tar

# # Alternative: Download entire folder
# !mkdir -p checkpoint
# # !gdown --folder https://drive.google.com/drive/folders/16vTNNzzAt4M1mmeLsOxSFDRzBogaNkJw --output checkpoint/
# !gdown --folder https://drive.google.com/drive/folders/1gJhqu00z536tPB3wwBw6zcWIxPjbh5Ri --output checkpoint/

# # Verify checkpoint
# !ls -lh checkpoint/

# %% [markdown]
# ## Step 4B: Full Training Run (4-6 hours)
#
# **Only run this after Step 4A succeeds!**
#
# This will take 4-6 hours. The notebook will keep running even if you close the browser.

# %%
# !pwd
# Out:
# /home/ec2-user/SageMaker/C-SFDA

# %%
# Full training - 25 epochs (4-6 hours)
# !python main_csfda.py \
    train_source=false \
    seed=2022 \
    data.dataset="VISDA-C" \
    data.data_root="./data/" \
    data.source_domains="[train]" \
    data.target_domains="[validation]" \
    data.batch_size=64 \
    data.workers=4 \
    model_src.arch="resnet101" \
    model_tta.src_log_dir="./checkpoint/VISDA-C" \
    learn.epochs=25 \
    optim.lr=2e-4 \
    multiprocessing_distributed=false \
    use_wandb=false
# Out:
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/hydra/_internal/defaults_list.py:251: UserWarning: In 'root': Defaults list is missing `_self_`. See https://hydra.cc/docs/1.2/upgrades/1.0_to_1.1/default_composition_order for more information
#   warnings.warn(msg, UserWarning)
# [INFO] 2025-11-15 06:59:49 main_csfda.py:96 Dataset: VISDA-C, Source domains: ['train'], Target domains: ['validation'], Pipeline: target
# [INFO] 2025-11-15 06:59:49 target_csfda.py:160 Start target training on train-validation...
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet101_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet101_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# /home/ec2-user/SageMaker/C-SFDA/classifier.py:40: UserWarning: nn.init.orthogonal is now deprecated in favor of nn.init.orthogonal_.
#   nn.init.orthogonal(m.weight.data)   # Initializing with orthogonal rows
# [INFO] 2025-11-15 06:59:50 classifier.py:67 Loaded from ./checkpoint/VISDA-C/best_train_2022.pth.tar; missing params: []
# [INFO] 2025-11-15 06:59:51 classifier.py:67 Loaded from ./checkpoint/VISDA-C/best_train_2022.pth.tar; missing params: []
# [INFO] 2025-11-15 06:59:51 target_csfda.py:195 1 - Created target model
# [INFO] 2025-11-15 06:59:51 target_csfda.py:49 Eval and labeling...
# 100%|█████████████████████████████████████████| 217/217 [01:24<00:00,  2.57it/s]
# [INFO] 2025-11-15 07:01:15 target_csfda.py:82 Accuracy of direct prediction: 51.89
# [INFO] 2025-11-15 07:01:15 utils.py:319 Accuracy per class: [75.45 15.31 47.85 64.89 59.22  7.71 80.37 31.32 62.39 31.39 88.86  5.41], mean: 47.51
# [INFO] 2025-11-15 07:01:15 target_csfda.py:218 2 - Computed initial pseudo labels
# [INFO] 2025-11-15 07:01:15 target_csfda.py:240 3 - Created train/val loader
# [INFO] 2025-11-15 07:01:15 target_csfda.py:244 4 -- Created Optimizer
# [INFO] 2025-11-15 07:01:15 target_csfda.py:245 Start Training ...
# [INFO] 2025-11-15 07:01:22 utils.py:278 Epoch: [1][  0/866]	Time  6.282 ( 6.282)	Loss 2.3218 (2.3218)	SSL-Acc@1   0.00 (  0.00)	CLS-Acc@1  51.56 ( 51.56)
# [INFO] 2025-11-15 07:06:20 utils.py:278 Epoch: [1][200/866]	Time  1.468 ( 1.516)	Loss 0.9351 (0.9817)	SSL-Acc@1   0.00 (  0.00)	CLS-Acc@1  67.19 ( 65.98)
# [INFO] 2025-11-15 07:11:17 utils.py:278 Epoch: [1][400/866]	Time  1.476 ( 1.500)	Loss 0.3746 (0.7862)	SSL-Acc@1   0.00 (  0.00)	CLS-Acc@1  76.56 ( 69.68)
# [INFO] 2025-11-15 07:16:13 utils.py:278 Epoch: [1][600/866]	Time  1.483 ( 1.493)	Loss 0.3688 (0.6962)	SSL-Acc@1   0.00 (  0.00)	CLS-Acc@1  79.69 ( 71.75)
# [INFO] 2025-11-15 07:21:08 utils.py:278 Epoch: [1][800/866]	Time  1.467 ( 1.489)	Loss 0.5411 (0.6316)	SSL-Acc@1   0.00 (  0.00)	CLS-Acc@1  79.69 ( 73.43)
# [INFO] 2025-11-15 07:22:43 target_csfda.py:49 Eval and labeling...
# 100%|█████████████████████████████████████████| 217/217 [01:24<00:00,  2.58it/s]
# [INFO] 2025-11-15 07:24:07 target_csfda.py:82 Accuracy of direct prediction: 79.09
# [INFO] 2025-11-15 07:24:07 utils.py:319 Accuracy per class: [95.12 72.29 86.2  67.05 94.71 90.6  93.29 81.47 90.81 66.99 91.74 41.06], mean: 80.94
# [INFO] 2025-11-15 07:24:13 utils.py:278 Epoch: [1][  0/866]	Time 90.071 ( 1.589)	Loss 0.1803 (0.6119)	SSL-Acc@1   0.00 (  0.00)	CLS-Acc@1  87.50 ( 73.92)
# [INFO] 2025-11-15 07:29:09 utils.py:278 Epoch: [1][200/866]	Time  1.473 ( 1.568)	Loss 0.3251 (0.5682)	SSL-Acc@1   0.00 (  0.00)	CLS-Acc@1  76.56 ( 75.15)
# [INFO] 2025-11-15 07:34:04 utils.py:278 Epoch: [1][400/866]	Time  1.462 ( 1.554)	Loss 0.5729 (0.5352)	SSL-Acc@1   0.00 (  0.00)	CLS-Acc@1  76.56 ( 76.05)
# [INFO] 2025-11-15 07:38:59 utils.py:278 Epoch: [1][600/866]	Time  1.470 ( 1.543)	Loss 0.3374 (0.5085)	SSL-Acc@1   0.00 (  0.00)	CLS-Acc@1  65.62 ( 76.80)
# [INFO] 2025-11-15 07:43:53 utils.py:278 Epoch: [1][800/866]	Time  1.482 ( 1.534)	Loss 0.2887 (0.4844)	SSL-Acc@1   0.00 (  0.00)	CLS-Acc@1  89.06 ( 77.42)
# [INFO] 2025-11-15 07:45:27 target_csfda.py:49 Eval and labeling...
# 100%|█████████████████████████████████████████| 217/217 [01:23<00:00,  2.58it/s]
# [INFO] 2025-11-15 07:46:52 target_csfda.py:82 Accuracy of direct prediction: 81.21
# [INFO] 2025-11-15 07:46:52 utils.py:319 Accuracy per class: [96.49 82.33 84.46 71.16 95.59 92.14 90.98 83.62 90.2  79.35 88.95 45.84], mean: 83.43
# [INFO] 2025-11-15 07:46:57 utils.py:278 Epoch: [1][  0/866]	Time 89.904 ( 1.582)	Loss 0.3147 (0.4775)	SSL-Acc@1   0.00 (  0.00)	CLS-Acc@1  84.38 ( 77.60)
# [INFO] 2025-11-15 07:56:46 utils.py:278 Epoch: [1][400/866]	Time  1.473 ( 1.562)	Loss 0.2561 (0.4426)	SSL-Acc@1   0.00 (  0.00)	CLS-Acc@1  82.81 ( 78.56)
# [INFO] 2025-11-15 08:01:41 utils.py:278 Epoch: [1][600/866]	Time  1.457 ( 1.554)	Loss 0.3245 (0.4304)	SSL-Acc@1   0.00 (  0.00)	CLS-Acc@1  84.38 ( 78.95)
# [INFO] 2025-11-15 08:06:35 utils.py:278 Epoch: [1][800/866]	Time  1.456 ( 1.547)	Loss 0.3520 (0.4179)	SSL-Acc@1   0.00 (  0.00)	CLS-Acc@1  79.69 ( 79.27)
# [INFO] 2025-11-15 08:08:10 target_csfda.py:49 Eval and labeling...
# 100%|█████████████████████████████████████████| 217/217 [01:24<00:00,  2.57it/s]
# [INFO] 2025-11-15 08:09:34 target_csfda.py:82 Accuracy of direct prediction: 81.21
# [INFO] 2025-11-15 08:09:34 utils.py:319 Accuracy per class: [96.13 81.55 87.8  71.17 95.52 88.92 91.37 83.68 90.2  87.64 92.59 38.37], mean: 83.74
# [INFO] 2025-11-15 08:24:25 utils.py:278 Epoch: [1][600/866]	Time  1.463 ( 1.560)	Loss 0.1972 (0.3840)	SSL-Acc@1   0.00 (  0.00)	CLS-Acc@1  84.38 ( 80.17)
# [INFO] 2025-11-15 08:29:20 utils.py:278 Epoch: [1][800/866]	Time  1.486 ( 1.555)	Loss 0.3375 (0.3747)	SSL-Acc@1   0.00 (  0.00)	CLS-Acc@1  79.69 ( 80.42)
# [INFO] 2025-11-15 08:30:54 target_csfda.py:49 Eval and labeling...
# 100%|█████████████████████████████████████████| 217/217 [01:24<00:00,  2.58it/s]
# [INFO] 2025-11-15 08:32:18 target_csfda.py:82 Accuracy of direct prediction: 83.23
# [INFO] 2025-11-15 08:32:18 utils.py:319 Accuracy per class: [97.67 84.14 86.89 75.05 95.93 92.63 94.   82.38 91.1  84.44 90.06 48.4 ], mean: 85.22
# [INFO] 2025-11-15 08:32:24 utils.py:278 Epoch: [1][  0/866]	Time 89.939 ( 1.578)	Loss 0.1178 (0.3719)	SSL-Acc@1   0.00 (  0.00)	CLS-Acc@1  81.25 ( 80.50)
# [INFO] 2025-11-15 08:47:06 utils.py:278 Epoch: [1][600/866]	Time  1.457 ( 1.562)	Loss 0.0799 (0.3506)	SSL-Acc@1   0.00 (  0.00)	CLS-Acc@1  85.94 ( 81.06)
# [INFO] 2025-11-15 08:52:01 utils.py:278 Epoch: [1][800/866]	Time  1.466 ( 1.558)	Loss 0.1828 (0.3447)	SSL-Acc@1   0.00 (  0.00)	CLS-Acc@1  84.38 ( 81.23)
# [INFO] 2025-11-15 08:53:35 target_csfda.py:49 Eval and labeling...
# 100%|█████████████████████████████████████████| 217/217 [01:24<00:00,  2.57it/s]
# [INFO] 2025-11-15 08:55:00 target_csfda.py:82 Accuracy of direct prediction: 82.94
# [INFO] 2025-11-15 08:55:00 utils.py:319 Accuracy per class: [94.62 81.55 86.01 74.12 96.72 90.94 92.36 82.48 92.22 88.08 93.41 48.2 ], mean: 85.06
# [INFO] 2025-11-15 09:14:42 utils.py:278 Epoch: [1][800/866]	Time  1.479 ( 1.561)	Loss 0.1820 (0.3226)	SSL-Acc@1   0.00 (  0.00)	CLS-Acc@1  82.81 ( 81.86)
# [INFO] 2025-11-15 09:16:17 target_csfda.py:49 Eval and labeling...
# 100%|█████████████████████████████████████████| 217/217 [01:24<00:00,  2.58it/s]
# [INFO] 2025-11-15 09:17:41 target_csfda.py:82 Accuracy of direct prediction: 82.80
# [INFO] 2025-11-15 09:17:41 utils.py:319 Accuracy per class: [97.53 83.45 88.1  70.84 95.12 94.07 92.13 83.95 91.34 84.92 92.63 50.05], mean: 85.34
# [INFO] 2025-11-15 09:17:47 utils.py:278 Epoch: [1][  0/866]	Time 89.939 ( 1.576)	Loss 0.2607 (0.3214)	SSL-Acc@1   0.00 (  0.00)	CLS-Acc@1  82.81 ( 81.90)
# [INFO] 2025-11-15 09:37:23 utils.py:278 Epoch: [1][800/866]	Time  1.456 ( 1.562)	Loss 0.1815 (0.3054)	SSL-Acc@1   0.00 (  0.00)	CLS-Acc@1  78.12 ( 82.30)
# [INFO] 2025-11-15 09:38:57 target_csfda.py:49 Eval and labeling...
# 100%|█████████████████████████████████████████| 217/217 [01:24<00:00,  2.57it/s]
# [INFO] 2025-11-15 09:40:22 target_csfda.py:82 Accuracy of direct prediction: 84.07
# [INFO] 2025-11-15 09:40:22 utils.py:319 Accuracy per class: [96.68 84.37 87.01 75.49 96.18 92.53 93.1  80.88 94.37 89.04 91.62 52.38], mean: 86.14
# [INFO] 2025-11-15 09:40:28 utils.py:278 Epoch: [1][  0/866]	Time 90.415 ( 1.575)	Loss 0.1911 (0.3041)	SSL-Acc@1   0.00 (  0.00)	CLS-Acc@1  89.06 ( 82.33)
# [INFO] 2025-11-15 09:45:22 utils.py:278 Epoch: [1][200/866]	Time  1.457 ( 1.572)	Loss 0.0830 (0.3003)	SSL-Acc@1   0.00 (  0.00)	CLS-Acc@1  92.19 ( 82.42)
# [INFO] 2025-11-15 09:50:16 utils.py:278 Epoch: [1][400/866]	Time  1.471 ( 1.569)	Loss 0.1956 (0.2967)	SSL-Acc@1   0.00 (  0.00)	CLS-Acc@1  75.00 ( 82.51)
# [INFO] 2025-11-15 09:55:10 utils.py:278 Epoch: [1][600/866]	Time  1.479 ( 1.566)	Loss 0.1982 (0.2932)	SSL-Acc@1   0.00 (  0.00)	CLS-Acc@1  87.50 ( 82.62)
# [INFO] 2025-11-15 10:00:04 utils.py:278 Epoch: [1][800/866]	Time  1.478 ( 1.563)	Loss 0.2106 (0.2899)	SSL-Acc@1   0.00 (  0.00)	CLS-Acc@1  87.50 ( 82.71)
# [INFO] 2025-11-15 10:01:39 target_csfda.py:49 Eval and labeling...
# 100%|█████████████████████████████████████████| 217/217 [01:24<00:00,  2.57it/s]
# [INFO] 2025-11-15 10:03:04 target_csfda.py:82 Accuracy of direct prediction: 83.77
# [INFO] 2025-11-15 10:03:04 utils.py:319 Accuracy per class: [96.74 81.58 85.91 72.44 96.31 92.53 93.67 82.85 92.66 87.42 93.79 56.02], mean: 85.99
# [INFO] 2025-11-15 10:03:09 utils.py:278 Epoch: [1][  0/866]	Time 90.635 ( 1.575)	Loss 0.0802 (0.2890)	SSL-Acc@1   0.00 (  0.00)	CLS-Acc@1  90.62 ( 82.73)
# [INFO] 2025-11-15 10:12:58 utils.py:278 Epoch: [1][400/866]	Time  1.487 ( 1.569)	Loss 0.1445 (0.2827)	SSL-Acc@1   0.00 (  0.00)	CLS-Acc@1  79.69 ( 82.90)
# [INFO] 2025-11-15 10:17:52 utils.py:278 Epoch: [1][600/866]	Time  1.456 ( 1.567)	Loss 0.1381 (0.2802)	SSL-Acc@1   0.00 (  0.00)	CLS-Acc@1  92.19 ( 82.98)
# [INFO] 2025-11-15 10:22:47 utils.py:278 Epoch: [1][800/866]	Time  1.485 ( 1.564)	Loss 0.1599 (0.2773)	SSL-Acc@1   0.00 (  0.00)	CLS-Acc@1  79.69 ( 83.05)
# [INFO] 2025-11-15 10:24:22 target_csfda.py:49 Eval and labeling...
# 100%|█████████████████████████████████████████| 217/217 [01:24<00:00,  2.56it/s]
# [INFO] 2025-11-15 10:25:47 target_csfda.py:82 Accuracy of direct prediction: 83.77
# [INFO] 2025-11-15 10:25:47 utils.py:319 Accuracy per class: [97.64 81.78 87.93 73.78 95.8  93.88 94.15 81.05 93.27 88.51 91.81 52.36], mean: 86.0
# [INFO] 2025-11-15 10:25:52 utils.py:278 Epoch: [1][  0/866]	Time 90.805 ( 1.575)	Loss 0.2607 (0.2764)	SSL-Acc@1   0.00 (  0.00)	CLS-Acc@1  85.94 ( 83.08)
# [INFO] 2025-11-15 10:30:47 utils.py:278 Epoch: [1][200/866]	Time  1.461 ( 1.572)	Loss 0.1970 (0.2741)	SSL-Acc@1   0.00 (  0.00)	CLS-Acc@1  79.69 ( 83.14)
# [INFO] 2025-11-15 10:35:40 utils.py:278 Epoch: [1][400/866]	Time  1.462 ( 1.570)	Loss 0.2084 (0.2718)	SSL-Acc@1   0.00 (  0.00)	CLS-Acc@1  81.25 ( 83.21)
# [INFO] 2025-11-15 10:40:35 utils.py:278 Epoch: [1][600/866]	Time  1.458 ( 1.568)	Loss 0.0337 (0.2693)	SSL-Acc@1   0.00 (  0.00)	CLS-Acc@1  85.94 ( 83.26)
# [INFO] 2025-11-15 10:45:29 utils.py:278 Epoch: [1][800/866]	Time  1.466 ( 1.565)	Loss 0.1328 (0.2668)	SSL-Acc@1   0.00 (  0.00)	CLS-Acc@1  82.81 ( 83.34)
# [INFO] 2025-11-15 10:47:04 target_csfda.py:49 Eval and labeling...
# 100%|█████████████████████████████████████████| 217/217 [01:23<00:00,  2.58it/s]
# [INFO] 2025-11-15 10:48:28 target_csfda.py:82 Accuracy of direct prediction: 84.11
# [INFO] 2025-11-15 10:48:28 utils.py:319 Accuracy per class: [96.85 83.4  84.71 73.21 96.99 94.36 93.93 82.5  92.48 89.79 91.97 57.08], mean: 86.44
# [INFO] 2025-11-15 10:48:34 utils.py:278 Epoch: [1][  0/866]	Time 89.971 ( 1.575)	Loss 0.2422 (0.2658)	SSL-Acc@1   0.00 (  0.00)	CLS-Acc@1  85.94 ( 83.36)
# [INFO] 2025-11-15 10:53:28 utils.py:278 Epoch: [1][200/866]	Time  1.505 ( 1.572)	Loss 0.1483 (0.2632)	SSL-Acc@1   0.00 (  0.00)	CLS-Acc@1  79.69 ( 83.42)
# [INFO] 2025-11-15 10:58:22 utils.py:278 Epoch: [1][400/866]	Time  1.490 ( 1.570)	Loss 0.2001 (0.2608)	SSL-Acc@1   0.00 (  0.00)	CLS-Acc@1  79.69 ( 83.47)
# [INFO] 2025-11-15 11:03:16 utils.py:278 Epoch: [1][600/866]	Time  1.482 ( 1.568)	Loss 0.2412 (0.2585)	SSL-Acc@1   0.00 (  0.00)	CLS-Acc@1  79.69 ( 83.53)
# [INFO] 2025-11-15 11:08:11 utils.py:278 Epoch: [1][800/866]	Time  1.473 ( 1.566)	Loss 0.1617 (0.2566)	SSL-Acc@1   0.00 (  0.00)	CLS-Acc@1  89.06 ( 83.58)
# [INFO] 2025-11-15 11:09:46 target_csfda.py:49 Eval and labeling...
# 100%|█████████████████████████████████████████| 217/217 [01:24<00:00,  2.58it/s]
# [INFO] 2025-11-15 11:11:10 target_csfda.py:82 Accuracy of direct prediction: 84.23
# [INFO] 2025-11-15 11:11:10 utils.py:319 Accuracy per class: [97.01 89.21 84.07 70.64 96.29 92.58 91.65 83.95 93.82 88.95 93.84 60.35], mean: 86.86
# [INFO] 2025-11-15 11:11:16 utils.py:278 Epoch: [1][  0/866]	Time 90.196 ( 1.574)	Loss 0.0705 (0.2558)	SSL-Acc@1   0.00 (  0.00)	CLS-Acc@1  84.38 ( 83.60)
# [INFO] 2025-11-15 11:16:10 utils.py:278 Epoch: [1][200/866]	Time  1.513 ( 1.572)	Loss 0.0965 (0.2537)	SSL-Acc@1   0.00 (  0.00)	CLS-Acc@1  89.06 ( 83.65)
# [INFO] 2025-11-15 11:21:04 utils.py:278 Epoch: [1][400/866]	Time  1.412 ( 1.570)	Loss 0.1514 (0.2516)	SSL-Acc@1   0.00 (  0.00)	CLS-Acc@1  85.94 ( 83.71)
# [INFO] 2025-11-15 11:25:58 utils.py:278 Epoch: [1][600/866]	Time  1.456 ( 1.568)	Loss 0.1397 (0.2497)	SSL-Acc@1   0.00 (  0.00)	CLS-Acc@1  87.50 ( 83.76)
# [INFO] 2025-11-15 11:30:53 utils.py:278 Epoch: [1][800/866]	Time  1.534 ( 1.567)	Loss 0.1038 (0.2476)	SSL-Acc@1   0.00 (  0.00)	CLS-Acc@1  93.75 ( 83.80)
# [INFO] 2025-11-15 11:32:27 target_csfda.py:49 Eval and labeling...
# 100%|█████████████████████████████████████████| 217/217 [01:24<00:00,  2.58it/s]
# [INFO] 2025-11-15 11:33:51 target_csfda.py:82 Accuracy of direct prediction: 84.30
# [INFO] 2025-11-15 11:33:51 utils.py:319 Accuracy per class: [97.72 86.56 86.57 71.25 96.25 93.59 92.27 84.5  91.73 90.18 91.76 60.36], mean: 86.9
# [INFO] 2025-11-15 11:33:57 utils.py:278 Epoch: [1][  0/866]	Time 90.320 ( 1.574)	Loss 0.4050 (0.2470)	SSL-Acc@1   0.00 (  0.00)	CLS-Acc@1  81.25 ( 83.82)
# [INFO] 2025-11-15 12:24:17 utils.py:278 Epoch: [1][200/866]	Time  1.478 ( 1.573)	Loss 0.0521 (0.2305)	SSL-Acc@1   0.00 (  0.00)	CLS-Acc@1  89.06 ( 84.23)
# [INFO] 2025-11-15 12:29:11 utils.py:278 Epoch: [1][400/866]	Time  1.472 ( 1.571)	Loss 0.0677 (0.2289)	SSL-Acc@1   0.00 (  0.00)	CLS-Acc@1  89.06 ( 84.27)
# [INFO] 2025-11-15 12:34:06 utils.py:278 Epoch: [1][600/866]	Time  1.472 ( 1.569)	Loss 0.1200 (0.2276)	SSL-Acc@1   0.00 (  0.00)	CLS-Acc@1  87.50 ( 84.30)
# [INFO] 2025-11-15 12:39:01 utils.py:278 Epoch: [1][800/866]	Time  1.481 ( 1.568)	Loss 0.1378 (0.2262)	SSL-Acc@1   0.00 (  0.00)	CLS-Acc@1  82.81 ( 84.34)
# [INFO] 2025-11-15 12:40:35 target_csfda.py:49 Eval and labeling...
# 100%|█████████████████████████████████████████| 217/217 [01:24<00:00,  2.58it/s]
# [INFO] 2025-11-15 12:42:00 target_csfda.py:82 Accuracy of direct prediction: 84.88
# [INFO] 2025-11-15 12:42:00 utils.py:319 Accuracy per class: [97.45 87.48 87.7  74.03 96.82 93.25 92.44 84.15 92.9  90.31 91.69 58.31], mean: 87.21
# [INFO] 2025-11-15 12:42:05 utils.py:278 Epoch: [1][  0/866]	Time 90.031 ( 1.574)	Loss 0.0711 (0.2258)	SSL-Acc@1   0.00 (  0.00)	CLS-Acc@1  90.62 ( 84.34)
# [INFO] 2025-11-15 12:47:00 utils.py:278 Epoch: [1][200/866]	Time  1.493 ( 1.573)	Loss 0.0755 (0.2245)	SSL-Acc@1   0.00 (  0.00)	CLS-Acc@1  87.50 ( 84.38)
# [INFO] 2025-11-15 12:51:54 utils.py:278 Epoch: [1][400/866]	Time  1.468 ( 1.571)	Loss 0.1501 (0.2230)	SSL-Acc@1   0.00 (  0.00)	CLS-Acc@1  89.06 ( 84.41)
# [INFO] 2025-11-15 12:56:48 utils.py:278 Epoch: [1][600/866]	Time  1.454 ( 1.570)	Loss 0.1021 (0.2216)	SSL-Acc@1   0.00 (  0.00)	CLS-Acc@1  92.19 ( 84.45)
# [INFO] 2025-11-15 13:01:43 utils.py:278 Epoch: [1][800/866]	Time  1.483 ( 1.568)	Loss 0.0810 (0.2202)	SSL-Acc@1   0.00 (  0.00)	CLS-Acc@1  87.50 ( 84.48)
# [INFO] 2025-11-15 13:03:18 target_csfda.py:49 Eval and labeling...
# 100%|█████████████████████████████████████████| 217/217 [01:24<00:00,  2.57it/s]
# [INFO] 2025-11-15 13:04:42 target_csfda.py:82 Accuracy of direct prediction: 84.51
# [INFO] 2025-11-15 13:04:42 utils.py:319 Accuracy per class: [96.57 88.29 85.52 70.58 96.67 92.92 92.86 83.38 93.1  90.18 93.89 61.64], mean: 87.13
# [INFO] 2025-11-15 13:04:48 utils.py:278 Epoch: [1][  0/866]	Time 90.449 ( 1.574)	Loss 0.1735 (0.2198)	SSL-Acc@1   0.00 (  0.00)	CLS-Acc@1  82.81 ( 84.49)
# [INFO] 2025-11-15 13:19:32 utils.py:278 Epoch: [1][600/866]	Time  1.476 ( 1.570)	Loss 0.5445 (0.2159)	SSL-Acc@1   0.00 (  0.00)	CLS-Acc@1  82.81 ( 84.57)
# [INFO] 2025-11-15 13:24:27 utils.py:278 Epoch: [1][800/866]	Time  1.481 ( 1.569)	Loss 0.1154 (0.2146)	SSL-Acc@1   0.00 (  0.00)	CLS-Acc@1  89.06 ( 84.61)
# [INFO] 2025-11-15 13:26:01 target_csfda.py:49 Eval and labeling...
#  92%|█████████████████████████████████████▊   | 200/217 [01:17<00:06,  2.60it/s][INFO] 2025-11-15 13:47:10 utils.py:278 Epoch: [1][800/866]	Time  1.484 ( 1.569)	Loss 0.1448 (0.2097)	SSL-Acc@1   0.00 (  0.00)	CLS-Acc@1  84.38 ( 84.74)
# [INFO] 2025-11-15 13:48:45 target_csfda.py:49 Eval and labeling...
# 100%|█████████████████████████████████████████| 217/217 [01:24<00:00,  2.58it/s]
# [INFO] 2025-11-15 13:50:09 target_csfda.py:82 Accuracy of direct prediction: 85.23
# [INFO] 2025-11-15 13:50:09 utils.py:319 Accuracy per class: [97.42 89.44 85.12 74.93 96.97 92.48 92.12 83.15 92.61 91.89 93.77 60.36], mean: 87.52
# [INFO] 2025-11-15 13:50:15 utils.py:278 Epoch: [1][  0/866]	Time 90.121 ( 1.574)	Loss 0.0990 (0.2093)	SSL-Acc@1   0.00 (  0.00)	CLS-Acc@1  89.06 ( 84.75)
# [INFO] 2025-11-15 13:55:10 utils.py:278 Epoch: [1][200/866]	Time  1.491 ( 1.573)	Loss 0.1101 (0.2082)	SSL-Acc@1   0.00 (  0.00)	CLS-Acc@1  89.06 ( 84.78)
# [INFO] 2025-11-15 14:00:05 utils.py:278 Epoch: [1][400/866]	Time  1.486 ( 1.572)	Loss 0.0691 (0.2071)	SSL-Acc@1   0.00 (  0.00)	CLS-Acc@1  89.06 ( 84.81)
# [INFO] 2025-11-15 14:05:00 utils.py:278 Epoch: [1][600/866]	Time  1.464 ( 1.570)	Loss 0.0565 (0.2061)	SSL-Acc@1   0.00 (  0.00)	CLS-Acc@1  90.62 ( 84.83)
# [INFO] 2025-11-15 14:09:55 utils.py:278 Epoch: [1][800/866]	Time  1.486 ( 1.569)	Loss 0.0871 (0.2050)	SSL-Acc@1   0.00 (  0.00)	CLS-Acc@1  81.25 ( 84.86)
# [INFO] 2025-11-15 14:11:30 target_csfda.py:49 Eval and labeling...
# 100%|█████████████████████████████████████████| 217/217 [01:24<00:00,  2.58it/s]
# [INFO] 2025-11-15 14:12:54 target_csfda.py:82 Accuracy of direct prediction: 84.65
# [INFO] 2025-11-15 14:12:54 utils.py:319 Accuracy per class: [97.7  87.77 88.49 72.05 96.42 92.92 93.67 83.82 92.28 90.   93.32 57.59], mean: 87.17
# [INFO] 2025-11-15 14:12:59 utils.py:278 Epoch: [1][  0/866]	Time 90.056 ( 1.574)	Loss 0.2459 (0.2047)	SSL-Acc@1   0.00 (  0.00)	CLS-Acc@1  90.62 ( 84.86)
# [INFO] 2025-11-15 14:17:54 utils.py:278 Epoch: [1][200/866]	Time  1.479 ( 1.573)	Loss 0.0624 (0.2036)	SSL-Acc@1   0.00 (  0.00)	CLS-Acc@1  82.81 ( 84.89)
# [INFO] 2025-11-15 14:22:49 utils.py:278 Epoch: [1][400/866]	Time  1.473 ( 1.572)	Loss 0.0604 (0.2026)	SSL-Acc@1   0.00 (  0.00)	CLS-Acc@1  84.38 ( 84.91)
# [INFO] 2025-11-15 14:27:44 utils.py:278 Epoch: [1][600/866]	Time  1.497 ( 1.571)	Loss 0.1719 (0.2017)	SSL-Acc@1   0.00 (  0.00)	CLS-Acc@1  78.12 ( 84.93)
# [INFO] 2025-11-15 14:32:40 utils.py:278 Epoch: [1][800/866]	Time  1.465 ( 1.570)	Loss 0.0519 (0.2007)	SSL-Acc@1   0.00 (  0.00)	CLS-Acc@1  82.81 ( 84.96)
# [INFO] 2025-11-15 14:34:14 target_csfda.py:49 Eval and labeling...
# 100%|█████████████████████████████████████████| 217/217 [01:24<00:00,  2.57it/s]
# [INFO] 2025-11-15 14:35:39 target_csfda.py:82 Accuracy of direct prediction: 84.37
# [INFO] 2025-11-15 14:35:39 utils.py:319 Accuracy per class: [97.5  89.32 87.01 68.99 96.55 94.12 91.91 81.9  92.66 91.41 94.26 61.91], mean: 87.3
# [INFO] 2025-11-15 14:35:45 utils.py:278 Epoch: [1][  0/866]	Time 90.383 ( 1.574)	Loss 0.0507 (0.2003)	SSL-Acc@1   0.00 (  0.00)	CLS-Acc@1  89.06 ( 84.97)
# [INFO] 2025-11-15 14:40:40 utils.py:278 Epoch: [1][200/866]	Time  1.462 ( 1.573)	Loss 0.0928 (0.1995)	SSL-Acc@1   0.00 (  0.00)	CLS-Acc@1  82.81 ( 84.99)
# [INFO] 2025-11-15 14:45:34 utils.py:278 Epoch: [1][400/866]	Time  1.465 ( 1.572)	Loss 0.0494 (0.1985)	SSL-Acc@1   0.00 (  0.00)	CLS-Acc@1  93.75 ( 85.02)
# [INFO] 2025-11-15 14:50:29 utils.py:278 Epoch: [1][600/866]	Time  1.474 ( 1.571)	Loss 0.1334 (0.1976)	SSL-Acc@1   0.00 (  0.00)	CLS-Acc@1  81.25 ( 85.04)
# [INFO] 2025-11-15 14:55:25 utils.py:278 Epoch: [1][800/866]	Time  1.467 ( 1.570)	Loss 0.0791 (0.1967)	SSL-Acc@1   0.00 (  0.00)	CLS-Acc@1  84.38 ( 85.06)
# [INFO] 2025-11-15 14:56:59 target_csfda.py:49 Eval and labeling...
# 100%|█████████████████████████████████████████| 217/217 [01:24<00:00,  2.58it/s]
# [INFO] 2025-11-15 14:58:23 target_csfda.py:82 Accuracy of direct prediction: 84.92
# [INFO] 2025-11-15 14:58:23 utils.py:319 Accuracy per class: [97.59 90.19 85.95 73.15 96.7  94.07 92.1  83.1  92.24 91.45 93.67 59.59], mean: 87.48
# [INFO] 2025-11-15 14:58:29 utils.py:278 Epoch: [1][  0/866]	Time 90.078 ( 1.574)	Loss 0.1786 (0.1964)	SSL-Acc@1   0.00 (  0.00)	CLS-Acc@1  82.81 ( 85.07)
# [INFO] 2025-11-15 15:18:08 utils.py:278 Epoch: [1][800/866]	Time  1.459 ( 1.570)	Loss 0.0834 (0.1928)	SSL-Acc@1   0.00 (  0.00)	CLS-Acc@1  93.75 ( 85.16)
# [INFO] 2025-11-15 15:19:42 target_csfda.py:49 Eval and labeling...
# 100%|█████████████████████████████████████████| 217/217 [01:24<00:00,  2.58it/s]
# [INFO] 2025-11-15 15:21:07 target_csfda.py:82 Accuracy of direct prediction: 85.00
# [INFO] 2025-11-15 15:21:07 utils.py:319 Accuracy per class: [97.59 88.89 84.88 73.46 96.03 94.6  93.18 80.42 92.99 93.07 94.92 60.38], mean: 87.53
# [INFO] 2025-11-15 15:21:12 utils.py:278 Epoch: [1][  0/866]	Time 90.080 ( 1.574)	Loss 0.1186 (0.1926)	SSL-Acc@1   0.00 (  0.00)	CLS-Acc@1  84.38 ( 85.17)
# [INFO] 2025-11-15 15:26:07 utils.py:278 Epoch: [1][200/866]	Time  1.479 ( 1.573)	Loss 0.4009 (0.1917)	SSL-Acc@1   0.00 (  0.00)	CLS-Acc@1  84.38 ( 85.19)
# [INFO] 2025-11-15 15:31:02 utils.py:278 Epoch: [1][400/866]	Time  1.469 ( 1.572)	Loss 0.0198 (0.1910)	SSL-Acc@1   0.00 (  0.00)	CLS-Acc@1  87.50 ( 85.21)
# [INFO] 2025-11-15 15:35:56 utils.py:278 Epoch: [1][600/866]	Time  1.468 ( 1.571)	Loss 0.1946 (0.1902)	SSL-Acc@1   0.00 (  0.00)	CLS-Acc@1  82.81 ( 85.23)
# [INFO] 2025-11-15 15:40:51 utils.py:278 Epoch: [1][800/866]	Time  1.509 ( 1.570)	Loss 0.0463 (0.1894)	SSL-Acc@1   0.00 (  0.00)	CLS-Acc@1  87.50 ( 85.25)
# [INFO] 2025-11-15 15:42:26 target_csfda.py:49 Eval and labeling...
# 100%|█████████████████████████████████████████| 217/217 [01:24<00:00,  2.58it/s]
# [INFO] 2025-11-15 15:43:50 target_csfda.py:82 Accuracy of direct prediction: 84.89
# [INFO] 2025-11-15 15:43:50 utils.py:319 Accuracy per class: [97.37 89.64 84.84 72.79 97.06 94.02 92.34 83.1  91.16 91.76 94.69 60.78], mean: 87.46
# [INFO] 2025-11-15 15:43:56 utils.py:278 Epoch: [1][  0/866]	Time 90.142 ( 1.574)	Loss 0.0526 (0.1891)	SSL-Acc@1   0.00 (  0.00)	CLS-Acc@1  90.62 ( 85.25)
# Error executing job with overrides: ['train_source=false', 'seed=2022', 'data.dataset=VISDA-C', 'data.data_root=./data/', 'data.source_domains=[train]', 'data.target_domains=[validation]', 'data.batch_size=64', 'data.workers=4', 'model_src.arch=resnet101', 'model_tta.src_log_dir=./checkpoint/VISDA-C', 'learn.epochs=25', 'optim.lr=2e-4', 'multiprocessing_distributed=false', 'use_wandb=false']
# Traceback (most recent call last):
#   File "/home/ec2-user/SageMaker/C-SFDA/main_csfda.py", line 45, in main
#     main_worker(args.gpu, ngpus_per_node, args)
#   File "/home/ec2-user/SageMaker/C-SFDA/main_csfda.py", line 141, in main_worker
#     train_target_csfda(args)
#   File "/home/ec2-user/SageMaker/C-SFDA/target_csfda.py", line 252, in train_target_domain
#     train_csfda(train_loader, val_loader, model, optimizer,  args)
#   File "/home/ec2-user/SageMaker/C-SFDA/target_csfda.py", line 486, in train_csfda
#     con_coeffs[ind] = con_coeff
# IndexError: index 20000 is out of bounds for axis 0 with size 20000
#
# Set the environment variable HYDRA_FULL_ERROR=1 for a complete stack trace.

# %%
import numpy as np

stats = np.load('training_stats.npz', allow_pickle=True)
print("Files in npz:", stats.files)

for key in stats.files:
    data = stats[key]
    if hasattr(data, 'shape'):
        print(f"{key}: shape {data.shape}, dtype {data.dtype}")
    else:
        print(f"{key}: {type(data)}")
# Out:
# Files in npz: ['pseudo_label_acc', 'acc_class', 'conf', 'unc', 'labeled_loss_coeff', 'con_coeff', 'ce_loss', 'con_loss', 'prop_loss', 'sel_Samples', 'unsel_samples']
# pseudo_label_acc: shape (20000,), dtype float64
# acc_class: shape (23,), dtype float64
# conf: shape (20000,), dtype float32
# unc: shape (20000,), dtype float32
# labeled_loss_coeff: shape (20000,), dtype float32
# con_coeff: shape (20000,), dtype float64
# ce_loss: shape (20000,), dtype float32
# con_loss: shape (20000,), dtype float32
# prop_loss: shape (20000,), dtype float32
# sel_Samples: shape (20000,), dtype int64
# unsel_samples: shape (20000,), dtype int64

# %% [markdown]
# ## Step 4A: Quick Test Run (10-15 minutes)
#
# **Run this first to verify everything works!**
#
# This will do 1 epoch to test:
# - Dataset loads correctly
# - Checkpoint loads
# - Model initializes
# - Training loop runs
# - Output saves properly
#
# Once this succeeds, skip to Step 4B for full training.

# %%
# # Quick test run - just 1 epoch to verify everything works
# # Use sys.executable to ensure we're using the notebook's Python with correct PyTorch
# import sys
# python_path = sys.executable
# print(f"Using Python: {python_path}")

# !{python_path} main_csfda.py \
#     train_source=false \
#     seed=2022 \
#     data.dataset="VISDA-C" \
#     data.data_root="./data/" \
#     data.source_domains="[train]" \
#     data.target_domains="[validation]" \
#     data.batch_size=64 \
#     data.workers=4 \
#     model_src.arch="resnet101" \
#     model_tta.src_log_dir="./checkpoint/VISDA-C" \
#     learn.epochs=1 \
#     optim.lr=2e-4 \
#     multiprocessing_distributed=false \
#     use_wandb=false
# Out:
# Using Python: /home/ec2-user/anaconda3/envs/python3/bin/python
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/hydra/_internal/defaults_list.py:251: UserWarning: In 'root': Defaults list is missing `_self_`. See https://hydra.cc/docs/1.2/upgrades/1.0_to_1.1/default_composition_order for more information
#   warnings.warn(msg, UserWarning)
# [INFO] 2025-11-15 04:34:15 main_csfda.py:96 Dataset: VISDA-C, Source domains: ['train'], Target domains: ['validation'], Pipeline: target
# [INFO] 2025-11-15 04:34:15 target_csfda.py:160 Start target training on train-validation...
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet101_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet101_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/resnet101-63fe2227.pth" to /home/ec2-user/.cache/torch/hub/checkpoints/resnet101-63fe2227.pth
# 100%|█████████████████████████████████████████| 171M/171M [00:00<00:00, 304MB/s]
# /home/ec2-user/SageMaker/C-SFDA/classifier.py:40: UserWarning: nn.init.orthogonal is now deprecated in favor of nn.init.orthogonal_.
#   nn.init.orthogonal(m.weight.data)   # Initializing with orthogonal rows
# [INFO] 2025-11-15 04:34:18 classifier.py:67 Loaded from ./checkpoint/VISDA-C/best_train_2022.pth.tar; missing params: []
# [INFO] 2025-11-15 04:34:19 classifier.py:67 Loaded from ./checkpoint/VISDA-C/best_train_2022.pth.tar; missing params: []
# [INFO] 2025-11-15 04:34:20 target_csfda.py:195 1 - Created target model
# [INFO] 2025-11-15 04:34:20 target_csfda.py:49 Eval and labeling...
# 100%|█████████████████████████████████████████| 217/217 [01:51<00:00,  1.94it/s]
# [INFO] 2025-11-15 04:36:12 target_csfda.py:82 Accuracy of direct prediction: 51.89
# [INFO] 2025-11-15 04:36:12 utils.py:319 Accuracy per class: [75.45 15.31 47.85 64.89 59.22  7.71 80.37 31.32 62.39 31.39 88.86  5.41], mean: 47.51
# [INFO] 2025-11-15 04:36:12 target_csfda.py:218 2 - Computed initial pseudo labels
# [INFO] 2025-11-15 04:36:12 target_csfda.py:240 3 - Created train/val loader
# [INFO] 2025-11-15 04:36:12 target_csfda.py:244 4 -- Created Optimizer
# [INFO] 2025-11-15 04:36:12 target_csfda.py:245 Start Training ...
# [INFO] 2025-11-15 04:36:28 utils.py:278 Epoch: [1][  0/866]	Time 15.672 (15.672)	Loss 2.3218 (2.3218)	SSL-Acc@1   0.00 (  0.00)	CLS-Acc@1  51.56 ( 51.56)
# [INFO] 2025-11-15 04:41:25 utils.py:278 Epoch: [1][200/866]	Time  1.493 ( 1.557)	Loss 0.7961 (0.9844)	SSL-Acc@1   0.00 (  0.00)	CLS-Acc@1  67.19 ( 65.62)
# [INFO] 2025-11-15 04:46:22 utils.py:278 Epoch: [1][400/866]	Time  1.511 ( 1.520)	Loss 0.3232 (0.7903)	SSL-Acc@1   0.00 (  0.00)	CLS-Acc@1  76.56 ( 69.53)
# [INFO] 2025-11-15 04:51:18 utils.py:278 Epoch: [1][600/866]	Time  1.507 ( 1.507)	Loss 0.3470 (0.6933)	SSL-Acc@1   0.00 (  0.00)	CLS-Acc@1  75.00 ( 72.00)
# [INFO] 2025-11-15 04:56:13 utils.py:278 Epoch: [1][800/866]	Time  1.505 ( 1.500)	Loss 0.6911 (0.6321)	SSL-Acc@1   0.00 (  0.00)	CLS-Acc@1  76.56 ( 73.76)
# [INFO] 2025-11-15 04:57:48 target_csfda.py:49 Eval and labeling...
# 100%|█████████████████████████████████████████| 217/217 [01:24<00:00,  2.57it/s]
# [INFO] 2025-11-15 04:59:13 target_csfda.py:82 Accuracy of direct prediction: 78.17
# [INFO] 2025-11-15 04:59:13 utils.py:319 Accuracy per class: [95.61 76.78 86.44 65.96 95.48 62.51 93.37 78.12 92.13 73.43 90.13 40.19], mean: 79.18
# [INFO] 2025-11-15 04:59:14 target_csfda.py:257 Saved checkpoint ./checkpoint/checkpoint_0001_train-validation-None_2022.pth.tar

# %% [markdown]
# ## Step 5: Check Results

# %%
# List output files
# !find output/ -name "*.pth.tar" -o -name "*.txt" -o -name "*.yaml" | head -20
# Out:
# output/VISDA-C/test/.hydra-2022/overrides.yaml
# output/VISDA-C/test/.hydra-2022/hydra.yaml
# output/VISDA-C/test/.hydra-2022/config.yaml

# %%
# Read final results (adjust path based on actual output)
# !tail -50 output/VISDA-C/*/logs.txt 2>/dev/null || echo "Check output/ directory structure"
# Out:
# Check output/ directory structure

# %%
# Download results
# !zip -r stage2_results.zip output/
from IPython.display import FileLink
FileLink('stage2_results.zip')
# Out:
#   adding: output/ (stored 0%)
#   adding: output/VISDA-C/ (stored 0%)
#   adding: output/VISDA-C/test/ (stored 0%)
#   adding: output/VISDA-C/test/.hydra-2022/ (stored 0%)
#   adding: output/VISDA-C/test/.hydra-2022/overrides.yaml (deflated 38%)
#   adding: output/VISDA-C/test/.hydra-2022/hydra.yaml (deflated 66%)
#   adding: output/VISDA-C/test/.hydra-2022/config.yaml (deflated 46%)
#   adding: output/VISDA-C/test/.ipynb_checkpoints/ (stored 0%)
#   adding: output/VISDA-C/test/.ipynb_checkpoints/main_csfda-checkpoint.log (stored 0%)
#   adding: output/VISDA-C/test/main_csfda.log (stored 0%)
# /home/ec2-user/SageMaker/C-SFDA/stage2_results.zip

# %% [markdown]
# ## Expected Results
#
# According to the paper, on VisDA-C you should see:
# - **Test Accuracy:** ~85%
# - **Per-class Average:** ~83-85%
